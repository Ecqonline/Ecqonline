# %% [markdown]
# <a href="https://colab.research.google.com/github/Ecqonline/Ecqonline/blob/main/PYTHON_ESTRUTURA_DE_CONDICAO_IF_TAREFA_COMPLEMENTAR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center><img src="https://raw.githubusercontent.com/rafael-arevalo/orbeai/master/Logo-Orbe-sem-fundo.png" height="300px"></center>
#
#
# # **PYTHON: estrutura de condição IF - Tarefa complementar.**

# %% [markdown]
# ## **01 - ESTRUTURA DE CONDIÇÃO IF**

# %% [markdown]
# Escreva um programa que:
#  * Aprove ou não um
# empréstimo para a compra de uma
# casa.
#
#   * Ele precisa conter:
#     * Valor da casa
#     * Salário do comprador
#     * Em quantos anos ele vai pagar
#     * O valor da prestação não pode
# exceder 30% do salário.
#
# Salve em variáveis o que for preciso.

# %% [markdown]
# | Você irá usar os comandos: | Para que servem:                        |
# |----------------------------|-----------------------------------------|
# |           print()          | imprimir                                |
# |           input()          | coletar dados                           |
# |             if             | estabelecer uma estrutura de condição   |
# |            else            | estabelecer outra estrutura de condição |
# |           float()          | transformar um dado em float            |
# |          variaveis         | salvar um conteúdo que for preciso      |

# %% [markdown]
# ### **01. RESULTADO DO PROGRAMA:**
#
#
#
#
# ![Sem título.png](data:image/png;base64,...)

# %%
# Colocando nosso título

# Coletando as variáveis 

# Fazendo o cálculo 


# Imprimindo "RESPOSTA DA ANÁLISE"


# Estabelecendo a condição


# Estabelecendo outra condição, caso a primeira não seja verdadeira

# %%
#@title Clique aqui para ver a resposta.

# Colocando nosso título
print(f'-'*50)
print(f'CÁLCULO DE APROVAÇÃO DE CRÉDITO')
print(f'-'*50)
print('\n')

#Coletando as variáveis 
valor_casa = float(input('Qual o valor da casa '))
salario = float(input('Qual o seu salário '))
anos = float(input('Deseja pagar a casa em quantos anos? '))

# Fazendo o cálculo 
parcelas = valor_casa / (anos*12)
valor_minimo=(salario/100)*30

# Imprimindo "RESPOSTA DA ANÁLISE"
print(f'-'*50)
print(f'RESPOSTA DA ANÁLISE')
print(f'-'*50)

# Estabelecendo a condição
if parcelas < valor_minimo:
  print(f'CRÉDITO APROVADO!')
  print(f'O valor da parcela é de R$ {parcelas:.2f}')

# Estabelecendo outra condição, caso a primeira não seja verdadeira
else:
  print(f'Parcelamento NÃO APROVADO')
  print(f'As parcelas de R$ {parcelas:.2f} são muito altas')

# %% [markdown]
# ## **02 - ESTRUTURA DE CONDIÇÃO IF**

# %% [markdown]
# Crie um chatbot de uma pizzaria, ele precisa:
#
# * Coletar o nome do cliente.
# * Imprimir um cardápio para o cliente :
#   * Marguerita por 36,0 reais.
#   * Napolitana por 44,0 reais.
# * Perguntar o sabor da pizza para o cliente e aceitar apenas os sabores do cardápio.
# * Perguntar qual a forma de pagamento para o cliente.
# * Imprimir um texto com o nome do cliente informando o valor do pedido.
#
# Faça um aninhamento de estrutura de condições se for preciso, em outras palavras, use um **`if`** dentro de outro **`if`**, se preciso.

# %% [markdown]
# | Você irá usar os comandos: | Para que servem:                                                                                      |
# |----------------------------|-------------------------------------------------------------------------------------------------------|
# |           print()          | Imprimir.                                                                                             |
# |           input()          | Coletar dados.                                                                                        |
# |             if             | Estabelecer uma estrutura de condição.                                                                |
# |            elif            | Estabelecer uma outra estrutura de condição, caso a primeira não satisfaça.                           |
# |            str()           | Transformar um dado em string.                                                                        |
# |           upper()          | Retorna um string todo em maiúsculas.                                                                 |
# |           strip()          | Tira e verifica os caracteres iniciais e finais contra um conjunto definido pelo usuário.             |
# |          format()          | Nesse caso será para inserir um valor em um texto com {}.                                             |
# |         in e not in        | Os operadores 'in' e 'not in' verificam se o dado à sua esquerda está contido na lista à sua direita. |

# %% [markdown]
# ### **02 RESULTADO *EXEMPLO* DO PROGRAMA:**
#
#
# ![Sem título.png](data:image/png;base64,...)

# %%
# Colocando o título


# Usando o comando input() para coletar o nome

# Imprimindo o cardápio e usando o comando input() para coletar o pedido


# Caso o pedido não esteja disponível no Menu


# Caso o pedido esteja disponível no menu

# %%
#@title Clique aqui para ver a resposta.

# Colocando o título
print(f'-'*50)
print(f'Obrigado por escolher a nossa Pizzaria!')
print(f'-'*50)
print('\n')

# Usando o comando input() para coletar o nome
print(f'-'*50)
nome = input("Qual seu nome? Resposta: ")
print(f'-'*50)

# Imprimindo o cardápio e usando o comando input() para coletar o pedido
print("Perfeito {} hoje temos disponível dois sabores: \n -> Marguerita por R$ 36,0 \n -> Napolita por R$ 40,0".format(nome))
pedido = str (input('Qual o seu pedido? Resposta: ')).strip().upper()[0]

print(f'-'*50)

# Caso o pedido não esteja disponível no Menu
if pedido not in 'MN':
  print(f'-'*50)
  pedido = str (input('Hmmm, esse sabor não temos, por favor, escolha um prato do nosso Menu. Resposta: ')).strip().upper()[0]
  print(f'-'*50)

# Caso o pedido esteja disponível no menu
if pedido in 'MN':

  if pedido == 'M':
    print(f'-'*50)
    print("Obrigado {} o valor total do seu pedido é de R$ 36,00".format(nome))
    forma_de_pagamento = input("Qual a forma de pagamento? Resposta: ").strip().upper()[0]


  elif pedido == 'N':
    print(f'-'*50)
    print("Obrigado {} o valor total do seu pedido é de R$ 40,00".format(nome))
    forma_de_pagamento = input("Qual a forma de pagamento? Resposta: ")


print(f'-'*50)

# %% [markdown]
# ## **03 - ESTRUTURA DE CONDIÇÃO ELIF**

# %% [markdown]
# Escreva um programa que pergunte o salário de um funcionário e calcule o
# valor do aumento.
#
# Da seguinte forma:
# * Se o salário for até 1.000,00 reais ele terá um aumento de 20%
#
#
# * Se o salário for mais de R$ 1.000,00 até 5.000,00 reais terá um aumento de 15%
#
#
#
# * Se o salário for mais de 5.000,00 reais terá um aumento de 10%
#
# Salve em variáveis o que for preciso.

# %% [markdown]
# | Você irá usar os comandos: | Para que servem:                        |
# |----------------------------|-----------------------------------------|
# |           print()          | imprimir                                |
# |           input()          | coletar dados                           |
# |             if             | estabelecer uma estrutura de condição   |
# |            else            | estabelecer outra estrutura de condição |
# |            elif            | estabelecer uma estrutura de condição   |
# |           float()          | transformar um dado em float            |
# |          variaveis         | salvar um conteúdo que for preciso      |

# %% [markdown]
# ### **03. RESULTADO DO PROGRAMA:**
#
# ![Sem título.png](data:image/png;base64,...)

# %%
# Imprimindo um título


# Coletando dados


# Estabelecendo uma estrutura de condição


# Estabelecendo outra estrutura de condição


# Estabelecendo uma estrutura de condição caso nenhuma das anteriores seje verdadeira


# Imprimindo a resposta

# %%
#@title Clique aqui para ver a resposta.

# Imprimindo um título
print(f'-'*50)
print(f'CÁLCULO DE REAJUSTE DE SALÁRIO')
print(f'-'*50)

# Coletando dados
salario = float(input('Qual o salario a ser analisado '))

# Estabelecendo uma estrutura de condição
if salario <= 1000:
  reajuste = '20 %'
  salario_novo = salario*1.20

# Estabelecendo outra estrutura de condição
elif salario < 5000:
  reajuste = '15 %'
  salario_novo = salario*1.15

# Estabelecendo uma estrutura de condição caso nenhuma das anteriores seje verdadeira
else:
  reajuste = '10 %'
  salario_novo = salario*1.10

# Imprimindo a resposta
print(f'-'*50)
print(f'RESPOSTA')
print(f'-'*50)
print(f'Este salário está na faixa de reajuste de {reajuste}')
print(f'Portanto ele irá de R$ {salario:.2f} para R$ {salario_novo:.2f}')
